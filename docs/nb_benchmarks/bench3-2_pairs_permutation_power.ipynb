# %% [markdown]
# # Bench 3-2: Pairs Permutation (SPICE) — Power
#
# **Placeholder — not yet implemented.**
#
# Will benchmark the statistical power of `permute(what='pairs')` / `paired_colocalization()`
# (the SPICE bijection null) as a function of inter-subject correspondence strength.
# Ground truth: subject-level maps constructed with a known shared component.
# Companion to `bench3-1_pairs_permutation_fpr`.
