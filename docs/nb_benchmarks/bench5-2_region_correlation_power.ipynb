# %% [markdown]
# # Bench 5-2: Region Correlation — Power
#
# **Placeholder — not yet implemented.**
#
# Will benchmark the statistical power of `regional_influence()` LOO statistics as a function
# of the spatial extent and strength of a focal regional effect.
# Ground truth: maps with a known subset of regions artificially boosted.
# Companion to `bench5-1_region_correlation_fpr`.
