# %% [markdown]
# # Bench 6-1: Multiple Comparison Correction
#
# **Placeholder — not yet implemented.**
#
# Will benchmark the family-wise error rate (FWER) and false discovery rate (FDR) of NiSpace's
# multiple comparison correction methods (`maxT`, FDR/Benjamini-Hochberg, Sidak-Meff)
# across a realistic number of simultaneously tested brain maps.
# Ground truth: GRF-based null maps → all tests under H0, FWER/FDR should equal α.
