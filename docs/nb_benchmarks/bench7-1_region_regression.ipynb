# %% [markdown]
# # Bench 7-1: Region Regression (Covariate Control)
#
# **Placeholder — not yet implemented.**
#
# Will validate that `clean_y('between')` / covariate regression correctly removes
# between-region spatial confounds without destroying within-region colocalization signal.
# Directly motivated by issue #87 (clean_y bug that collapsed signal to ~0).
# Ground truth: maps with a known spatial confound added on top of a known signal;
# regression should recover the original signal correlation.
