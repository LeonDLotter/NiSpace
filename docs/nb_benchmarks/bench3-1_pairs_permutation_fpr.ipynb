# %% [markdown]
# # Bench 3-1: Pairs Permutation (SPICE) — FPR
#
# **Placeholder — not yet implemented.**
#
# Will benchmark the false positive rate of `permute(what='pairs')` / `paired_colocalization()`
# (the SPICE bijection null) under the null hypothesis of no inter-subject correspondence.
# Ground truth: independently sampled subject-level GRF maps → true rho=0 per pair.
# Tests whether the bijection null is well-calibrated across SA levels and parcellation types.
