# %% [markdown]
# # Bench 4-2: Set Resampling (XSEA) — Power
#
# **Placeholder — not yet implemented.**
#
# Will benchmark the statistical power of XSEA set resampling (`permute(what='sets')`) as a function
# of the fraction of enriched genes in a set and the strength of the spatial signal.
# Ground truth: synthetic gene sets constructed to have a known proportion of 'signal' members.
# Companion to `bench4-1_set_resampling_fpr`.
