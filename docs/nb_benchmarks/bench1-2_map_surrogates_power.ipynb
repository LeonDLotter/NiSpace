# %% [markdown]
# # Bench 1-2: Map Surrogates — Power
#
# **Placeholder — not yet implemented.**
#
# Will benchmark the statistical power (true positive rate) of spatial null model methods
# (`moran`, `cornblath`, etc.) as a function of effect size and spatial autocorrelation level.
# Ground truth: `y = rho * x + sqrt(1 - rho²) * z` where x, z are independent GRF maps of the same alpha,
# giving an exact population-level correlation rho with SA preserved.
# Test rho ∈ {0.3, 0.5, 0.7} at alpha=3.0.
# Companion to `bench1-1_map_surrogates_fpr`.
