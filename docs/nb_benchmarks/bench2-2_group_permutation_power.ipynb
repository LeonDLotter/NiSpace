# %% [markdown]
# # Bench 2-2: Group Permutation — Power
#
# **Placeholder — not yet implemented.**
#
# Will benchmark the statistical power (true positive rate) of `permute(what='groups')` as a function
# of group effect size and spatial autocorrelation level.
# Ground truth: group difference maps constructed from GRF-based maps with known effect sizes.
# Companion to `bench2-1_group_permutation_fpr`.
