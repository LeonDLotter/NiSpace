# %% [markdown]
# # Visualizing colocalization results
#
# NiSpace has two integrated visualization methods that work directly on the fitted NiSpace object:
#
# - `nsp.plot()` — colocalization results (bar charts, scatter plots, …)
# - `nsp.plot_brain()` — brain surface or volume rendering of input/reference maps
#
# This notebook walks through the customization options for both. For standalone brain plotting (independent of any NiSpace analysis), see [Notebook 8](intro08_brainplot.ipynb).

# %%
import tqdm.notebook
tqdm.notebook.tqdm = tqdm.tqdm

import numpy as np
import matplotlib.pyplot as plt

# %%
from nispace.datasets import fetch_reference, fetch_example
from nispace.io import load_img
from nispace.api import NiSpace

# set up two analyses: pain map (single map) and anorexia nervosa (group comparison)
pet_maps = fetch_reference("pet", parcellation="Yan200",
                           collection="UniqueTracers", print_references=False)

# single map: pain
nsp_pain = NiSpace(x=pet_maps, y=load_img("neuroquery/pain.nii.gz"),
                   y_labels="Pain", parcellation="Yan200", seed=42, n_proc=4)
nsp_pain.fit()
nsp_pain.colocalize("spearman")
nsp_pain.permute("maps", n_perm=1000, p_tails="upper")

# group comparison: anorexia nervosa (simulated data — not for scientific use)
an_data = fetch_example("anorexianervosa", parcellation="Yan200")
groups = an_data.index.str.extract(r'(AN|HC)$')[0].values

nsp_an = NiSpace(x=pet_maps, y=an_data, parcellation="Yan200", seed=42, n_proc=4)
nsp_an.fit()
nsp_an.transform_y("hedges(a,b)", groups=groups)
nsp_an.colocalize("spearman")
nsp_an.permute("groups", groups=groups, n_perm=1000)
# Out:
# INFO | 16/07/26 23:05:34 | nispace.datasets: Loading pet maps.
# INFO | 16/07/26 23:05:34 | nispace.datasets: Loading integrated collection 'UniqueTracers' for dataset 'pet'.
# INFO | 16/07/26 23:05:34 | nispace.datasets: Filtering maps by collection.
# INFO | 16/07/26 23:05:34 | nispace.datasets: Loading data parcellated with 'Yan200'
# INFO | 16/07/26 23:05:34 | nispace.api: *** NiSpace.fit() - Data extraction and preparation. ***
# INFO | 16/07/26 23:05:34 | nispace.core.parcellation: Building cortex Parcellation for 'Yan200' from library. DOI: 10.1016/j.neuroimage.2023.120010
# INFO | 16/07/26 23:05:34 | nispace.core.parcellation: Available spaces: MNI152NLin2009cAsym, MNI152NLin6Asym, fsLR, fsaverage
# INFO | 16/07/26 23:05:35 | nispace.core.parcellation: Parcellation 'Yan200': validation passed.
# INFO | 16/07/26 23:05:35 | nispace.core.parcellation: Lazy-loading parcellation image for space 'MNI152NLin2009cAsym'.
# INFO | 16/07/26 23:05:35 | nispace.core.parcellation: Parcellation 'Yan200': active space set to 'MNI152NLin2009cAsym'.
# INFO | 16/07/26 23:05:35 | nispace.api: Checking input data for 'x' (should be, e.g., PET data):
# INFO | 16/07/26 23:05:35 | nispace.io: Input type: DataFrame, assuming parcellated data with shape (n_files/subjects/etc, n_parcels).
# WARNING | 16/07/26 23:05:35 | nispace.io: Parcellated data contains nan values!
# INFO | 16/07/26 23:05:35 | nispace.api: Got 'x' data for 29 x 200 parcels.
# INFO | 16/07/26 23:05:35 | nispace.api: Checking input data for 'y' (should be, e.g., subject data):
# INFO | 16/07/26 23:05:35 | nispace.io: Input type: list, assuming imaging data.
# INFO | 16/07/26 23:05:35 | nispace.io: Background (bg) handling: ignoring bg: True (bg value: ['auto', 0.0]); dropping bg parcels: False
# INFO | 16/07/26 23:05:35 | nispace.io: Parcellating imaging data.
# Parcellating (4 proc): 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 122.32it/s]
# INFO | 16/07/26 23:05:39 | nispace.api: Got 'y' data for 1 x 200 parcels.
# INFO | 16/07/26 23:05:39 | nispace.api: Z-standardizing 'X' data.
# INFO | 16/07/26 23:05:39 | nispace.api: *** NiSpace.colocalize() - Estimating X & Y colocalizations. ***
# INFO | 16/07/26 23:05:39 | nispace.api: Running 'spearman' colocalization.
# INFO | 16/07/26 23:05:39 | nispace.api: Pre-ranking X and Y data.
# Colocalizing (spearman, 4 proc): 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 3175.10it/s]
# INFO | 16/07/26 23:05:42 | nispace.api: *** NiSpace.permute() - Estimate exact non-parametric p values. ***
# INFO | 16/07/26 23:05:42 | nispace.api: Permutation of: X maps.
# INFO | 16/07/26 23:05:42 | nispace.api: Using default null method 'moran' (parcellation null space: 'fsLR').
# INFO | 16/07/26 23:05:42 | nispace.core.parcellation: Lazy-loading parcellation image for space 'fsLR'.
# INFO | 16/07/26 23:05:42 | nispace.api: Loading observed colocalizations (method = 'spearman').
# INFO | 16/07/26 23:05:42 | nispace.core.permute: Generating null maps (n = 1000, null_method = 'moran').
# INFO | 16/07/26 23:05:42 | nispace.nulls: Null map generation: Assuming n = 29 data vector(s) for n = 200 parcels.
# INFO | 16/07/26 23:05:42 | nispace.nulls: Using provided distance matrix/matrices.
# Moran null maps (4 proc): 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 29/29 [00:00<00:00, 73.19it/s]
# INFO | 16/07/26 23:05:45 | nispace.nulls: Null data generation finished.
# INFO | 16/07/26 23:05:45 | nispace.core.permute: Z-standardizing null maps.
# Processing null arrays (4 proc): 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:01<00:00, 895.38it/s]
# Null colocalizations (spearman, 4 proc): 100%|█████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 7221.67it/s]
# INFO | 16/07/26 23:05:47 | nispace.core.permute: Calculating exact p-values (tails = {'rho': 'upper'}).
# INFO | 16/07/26 23:05:47 | nispace.datasets: Loading example dataset: 'anorexianervosa', parcellated with: Yan200.
# INFO | 16/07/26 23:05:47 | nispace.core.parcellation: Building cortex Parcellation for 'Yan200' from library. DOI: 10.1016/j.neuroimage.2023.120010
# INFO | 16/07/26 23:05:47 | nispace.core.parcellation: Available spaces: MNI152NLin2009cAsym, MNI152NLin6Asym, fsLR, fsaverage
# INFO | 16/07/26 23:05:48 | nispace.core.parcellation: Parcellation 'Yan200': validation passed.
# INFO | 16/07/26 23:05:48 | nispace.io: Input type: DataFrame, assuming parcellated data with shape (n_files/subjects/etc, n_parcels).
# WARNING | 16/07/26 23:05:48 | nispace.io: Parcellated data contains nan values!
# INFO | 16/07/26 23:05:48 | nispace.io: Input type: DataFrame, assuming parcellated data with shape (n_files/subjects/etc, n_parcels).
# Colocalizing (spearman, 4 proc): 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 3095.43it/s]
# INFO | 16/07/26 23:05:48 | nispace.core.parcellation: Lazy-loading parcellation image for space 'fsLR'.
# Permuting groups (4 proc): 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 744595.06it/s]
# Null transformations (spearman, 4 proc): 100%|█████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 3901.45it/s]
# Processing null arrays (4 proc): 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 3579.30it/s]
# Null colocalizations (spearman, 4 proc): 100%|████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 13128.70it/s]
# INFO | 16/07/26 23:05:49 | nispace.core.permute: Calculating exact p-values (tails = {'rho': 'two'}).

# %% [markdown]
# ## `nsp.plot()` — colocalization results
#
# ### Default output
#
# The default `plot()` shows a categorical bar chart of colocalization values, colored by neurotransmitter system, with the null distribution shaded in grey.

# %%
nsp_pain.plot()
# Out:
# INFO | 16/07/26 23:05:49 | nispace.plotting: Significance annotation: 0/29 p_uncorrected < 0.05, 0/29 p_corrected < 0.05 (no correction applied)
# (<Figure size 500x730 with 1 Axes>,
#  <Axes: title={'center': "$Spearman's\\ Rho$ colocalization\n(permutation of $X\\ maps$)"}, xlabel='$Rho$'>,
#  <seaborn._core.plot.Plotter at 0x1768a1280>)

# %% [markdown]
# ### Values: raw correlations, z-scores, or -log10(p)
#
# The `values` argument controls what's shown on the x-axis:
# - `"coloc"` — raw colocalization values (Spearman ρ, partial r, …)
# - `"z"` — null-normalized z-scores (colocalization scaled by null mean and sd)
# - `"p"` — −log₁₀(p), optionally with multiple comparison correction

# %%
# z-normalized values (makes effect sizes more comparable across maps)
nsp_pain.normalize_colocalizations() # we need to calculate the normalized scores first
nsp_pain.plot(values="z")
# Out:
# INFO | 16/07/26 23:05:49 | nispace.plotting: Significance annotation: 0/29 p_uncorrected < 0.05, 0/29 p_corrected < 0.05 (no correction applied)
# (<Figure size 500x730 with 1 Axes>,
#  <Axes: title={'center': "$Spearman's\\ Rho$ colocalization\n(permutation of $X\\ maps$ | normalized)"}, xlabel='$Rho$ (null-normalized Z)'>,
#  <seaborn._core.plot.Plotter at 0x1767da7c0>)

# %%
# -log10(p), with FDR correction marked
nsp_pain.plot(values="p")
# Out:
# (<Figure size 500x730 with 1 Axes>,
#  <Axes: title={'center': "$Spearman's\\ Rho$ colocalization\n(permutation of $X\\ maps$ | $p_{\\mathrm{uncorrected}}$)"}, xlabel='$-\\log_{10}(p)$'>,
#  <seaborn._core.plot.Plotter at 0x1762192b0>)

# %% [markdown]
# ### Sorting and filtering
#
# Use `sort_by` to reorder the bars, and `X_maps` to select a subset of reference maps.

# %%
# sort by colocalization value
nsp_pain.plot(sort_by="coloc")
# Out:
# INFO | 16/07/26 23:05:50 | nispace.plotting: Significance annotation: 0/29 p_uncorrected < 0.05, 0/29 p_corrected < 0.05 (no correction applied)
# (<Figure size 500x730 with 1 Axes>,
#  <Axes: title={'center': "$Spearman's\\ Rho$ colocalization\n(permutation of $X\\ maps$)"}, xlabel='$Rho$'>,
#  <seaborn._core.plot.Plotter at 0x376e80f40>)

# %%
# show only specific systems
nsp_pain.plot(
    X_maps=["VAChT", "NET", "MOR", "KOR", "CB1"],  # match by partial name
    sort_by="coloc"
)
# Out:
# INFO | 16/07/26 23:05:50 | nispace.plotting: Significance annotation: 0/5 p_uncorrected < 0.05, 0/5 p_corrected < 0.05 (no correction applied)
# (<Figure size 500x250 with 1 Axes>,
#  <Axes: title={'center': "$Spearman's\\ Rho$ colocalization\n(permutation of $X\\ maps$)"}, xlabel='$Rho$'>,
#  <seaborn._core.plot.Plotter at 0x376f88940>)

# %% [markdown]
# ### P-value annotations
#
# `annot_p` controls how significance markers are shown
# - `"stats"` — show filled and empty significance stars (default; filled -> corrected; empty -> raw values)
# - `"text"` - show raw p values as text
# - `"both"` — show stars and raw p value as text
# - `False` — no markers

# %%
nsp_pain.plot(annot_p="text")
# Out:
# INFO | 16/07/26 23:05:51 | nispace.plotting: Significance annotation: 0/29 p_uncorrected < 0.05, 0/29 p_corrected < 0.05 (no correction applied)
# (<Figure size 500x730 with 1 Axes>,
#  <Axes: title={'center': "$Spearman's\\ Rho$ colocalization\n(permutation of $X\\ maps$)"}, xlabel='$Rho$'>,
#  <seaborn._core.plot.Plotter at 0x37707df40>)

# %% [markdown]
# ### Passing to matplotlib
#
# `plot()` returns `(fig, ax, plot_object)`, so you can post-process the figure with standard matplotlib calls. You can also pass `fig` and `ax` to embed the plot in an existing figure.

# %%
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# important: also pass the figure level, otherwise legends will behave quite unpredictably
nsp_pain.plot(ax=axes[0], fig=fig, show=False, title="Pain map", sort_by="coloc")
nsp_an.plot(ax=axes[1], fig=fig, show=False, title="Anorexia nervosa (Hedges' g)", sort_by="coloc")

plt.tight_layout()
plt.show()
# Out:
# INFO | 16/07/26 23:05:51 | nispace.plotting: Significance annotation: 0/29 p_uncorrected < 0.05, 0/29 p_corrected < 0.05 (no correction applied)
# INFO | 16/07/26 23:05:51 | nispace.plotting: Significance annotation: 7/29 p_uncorrected < 0.05, 0/29 p_corrected < 0.05 (no correction applied)

# %% [markdown]
# ## `nsp.plot_brain()` — brain surface rendering
#
# ### Basic usage

# %%
# plot the Y data (pain map after parcellation)
nsp_pain.plot_brain(data="Y")
# Out:
# WARNING | 16/07/26 23:05:51 | nispace.plotting: Brain plotting in NiSpace is experimental. If things look off, feel free to raise a GitHub issue!
# INFO | 16/07/26 23:05:51 | nispace.plotting: brainplot: threshold='auto' → 0.0017398296622559428
# INFO | 16/07/26 23:05:51 | nispace.plotting: brainplot: kind='glass', img_mode='None', surf_space='None', mni_space='MNI152NLin2009cAsym', surf_mesh='inflated'
# (<Figure size 720x180 with 6 Axes>, [<Axes: >])

# %%
# plot a specific reference map
nsp_pain.plot_brain(data="X", maps="VAChT", symmetric_cmap=False)
# Out:
# WARNING | 16/07/26 23:05:55 | nispace.plotting: Brain plotting in NiSpace is experimental. If things look off, feel free to raise a GitHub issue!
# INFO | 16/07/26 23:05:55 | nispace.plotting: brainplot: threshold='auto' → 0.0001124086047639139
# INFO | 16/07/26 23:05:55 | nispace.plotting: brainplot: kind='glass', img_mode='None', surf_space='None', mni_space='MNI152NLin2009cAsym', surf_mesh='inflated'
# (<Figure size 720x180 with 6 Axes>, [<Axes: >])

# %% [markdown]
# ### Rendering modes
#
# The `kind` argument controls the rendering:
# - `"surface"` — inflated cortical surface (default for cortex-only parcellations)
# - `"glass"` — glass brain (transparent volumetric rendering)
# - `"slice"` — anatomical slices

# %%
nsp_pain.plot_brain(data="Y", kind="glass")
# Out:
# WARNING | 16/07/26 23:05:58 | nispace.plotting: Brain plotting in NiSpace is experimental. If things look off, feel free to raise a GitHub issue!
# INFO | 16/07/26 23:05:58 | nispace.plotting: brainplot: threshold='auto' → 0.0017398296622559428
# INFO | 16/07/26 23:05:58 | nispace.plotting: brainplot: kind='glass', img_mode='None', surf_space='None', mni_space='MNI152NLin2009cAsym', surf_mesh='inflated'
# (<Figure size 720x180 with 6 Axes>, [<Axes: >])

# %%
nsp_pain.plot_brain(data="Y", kind="slice")
# Out:
# WARNING | 16/07/26 23:06:02 | nispace.plotting: Brain plotting in NiSpace is experimental. If things look off, feel free to raise a GitHub issue!
# INFO | 16/07/26 23:06:02 | nispace.plotting: brainplot: threshold='auto' → 0.0017398296622559428
# INFO | 16/07/26 23:06:02 | nispace.plotting: brainplot: kind='slice', img_mode='None', surf_space='None', mni_space='MNI152NLin2009cAsym', surf_mesh='inflated'
# (<Figure size 700x180 with 7 Axes>, [<Axes: >])

# %% [markdown]
# ### Colormap and scale options

# %%
# custom colormap, fixed scale, colorbar label
nsp_pain.plot_brain(
    data="Y",
    cmap="viridis",
    symmetric_cmap=False,
    vmin=0,
    colorbar_label="z-score"
)
# Out:
# WARNING | 16/07/26 23:06:06 | nispace.plotting: Brain plotting in NiSpace is experimental. If things look off, feel free to raise a GitHub issue!
# INFO | 16/07/26 23:06:06 | nispace.plotting: brainplot: threshold='auto' → 0.0017398296622559428
# INFO | 16/07/26 23:06:06 | nispace.plotting: brainplot: kind='glass', img_mode='None', surf_space='None', mni_space='MNI152NLin2009cAsym', surf_mesh='inflated'
# (<Figure size 720x180 with 6 Axes>, [<Axes: >])

# %%
# plot multiple X maps with a shared color scale
nsp_pain.plot_brain(
    data="X",
    maps=["VAChT", "NET", "KOR"],  # only these three
    shared_colorscale=True,
    ncols=3,
    symmetric_cmap=False
)
# Out:
# WARNING | 16/07/26 23:06:10 | nispace.plotting: Brain plotting in NiSpace is experimental. If things look off, feel free to raise a GitHub issue!
# INFO | 16/07/26 23:06:10 | nispace.plotting: brainplot: threshold='auto' → 0.0001124086047639139
# INFO | 16/07/26 23:06:10 | nispace.plotting: brainplot: kind='glass', img_mode='None', surf_space='None', mni_space='MNI152NLin2009cAsym', surf_mesh='inflated'
# (<Figure size 2160x180 with 18 Axes>, [<Axes: >, <Axes: >, <Axes: >])

# %% [markdown]
# ### Surface mesh options

# %%
# pial surface instead of inflated
nsp_pain.plot_brain(data="Y", surf_mesh="pial")
# Out:
# WARNING | 16/07/26 23:06:21 | nispace.plotting: Brain plotting in NiSpace is experimental. If things look off, feel free to raise a GitHub issue!
# INFO | 16/07/26 23:06:21 | nispace.plotting: brainplot: threshold='auto' → 0.0017398296622559428
# INFO | 16/07/26 23:06:21 | nispace.plotting: brainplot: kind='glass', img_mode='None', surf_space='None', mni_space='MNI152NLin2009cAsym', surf_mesh='pial'
# (<Figure size 720x180 with 6 Axes>, [<Axes: >])

# %% [markdown]
# ## Summary
#
# **`nsp.plot()` key arguments:**
#
# | Argument | Options | Effect |
# |----------|---------|--------|
# | `values` | `"coloc"`, `"z"`, `"p"` | What to show on x-axis |
# | `mc_method` | `"meff"`, `"fdr_bh"`, `"bonferroni"`, `"maxT"`, … | Multiple comparison correction |
# | `sort_by` | `"coloc"`, `"p"`, `"set"` | Bar ordering |
# | `annot_p` | `"right"`, `"both"`, `False` | Significance markers |
# | `X_maps` | list of strings | Select subset of reference maps |
# | `ax` | matplotlib Axes | Embed in existing figure |
#
# **`nsp.plot_brain()` key arguments:**
#
# | Argument | Options | Effect |
# |----------|---------|--------|
# | `data` | `"Y"`, `"X"`, DataFrame | Which maps to render |
# | `maps` | string or list | Select subset of maps |
# | `kind` | `"surface"`, `"glass"`, `"slice"` | Rendering mode |
# | `cmap` | any matplotlib colormap | Colormap |
# | `symmetric_cmap` | bool | Zero-centered color scale |
# | `shared_colorscale` | bool | Same scale across all maps |
#
# Next: [Notebook 8](intro08_brainplot.ipynb) covers the standalone `brainplot()` function — useful whenever you want to visualize brain maps outside of a NiSpace analysis.
